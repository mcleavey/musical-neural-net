# %%
from playlist import make_playlist
from IPython.display import display,Audio,HTML

# %%
# !python make_test_train.py --example

# %%
# Optionally adjust 
#    --random_freq (from 0 to 1, how often to choose a random note rather than the most likely note)
#    --trunc (how many of the top model proposed guesses to consider - a smaller number means stay only to the most likely options)

# %%
# !python generate.py -model notewise_generator -output notewise_generator_samples --random_freq .8 --trunc 3
# Out:
# Loading network
# Preparing to generate a batch of 16 samples.
# Prompting network
# Generating new sample
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/0.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 2669
# Encoding Finished.
# Total bytes written: 2.13 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 0.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:09] Decoding of 0.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/1.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 3171
# Encoding Finished.
# Total bytes written: 2.53 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 1.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:22] Decoding of 1.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/2.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 5916
# Encoding Finished.
# Total bytes written: 4.71 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 2.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [2:34] Decoding of 2.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/3.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 3133
# Encoding Finished.
# Total bytes written: 2.50 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 3.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:21] Decoding of 3.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/4.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 2003
# Encoding Finished.
# Total bytes written: 1.60 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 4.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:52] Decoding of 4.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/5.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 3059
# Encoding Finished.
# Total bytes written: 2.44 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 5.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:19] Decoding of 5.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/6.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 5073
# Encoding Finished.
# Total bytes written: 4.04 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 6.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [2:12] Decoding of 6.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/7.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 1765
# Encoding Finished.
# Total bytes written: 1.41 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 7.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:46] Decoding of 7.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/8.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 3192
# Encoding Finished.
# Total bytes written: 2.54 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 8.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:23] Decoding of 8.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/9.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 2457
# Encoding Finished.
# Total bytes written: 1.96 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 9.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:04] Decoding of 9.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/10.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 2059
# Encoding Finished.
# Total bytes written: 1.64 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 10.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:53] Decoding of 10.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/11.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 1819
# Encoding Finished.
# Total bytes written: 1.45 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 11.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:47] Decoding of 11.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/12.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 5206
# Encoding Finished.
# Total bytes written: 4.15 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 12.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [2:15] Decoding of 12.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/13.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 1445
# Encoding Finished.
# Total bytes written: 1.15 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 13.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:37] Decoding of 13.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/14.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 3878
# Encoding Finished.
# Total bytes written: 3.09 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 14.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
# [1:41] Decoding of 14.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/15.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 3163
# Encoding Finished.
# Total bytes written: 2.52 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: 15.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [1:22] Decoding of 15.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt0.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 193
# Encoding Finished.
# Total bytes written: 158.19 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt0.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:05] Decoding of prompt0.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt1.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 317
# Encoding Finished.
# Total bytes written: 259.31 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt1.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:08] Decoding of prompt1.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt2.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 405
# Encoding Finished.
# Total bytes written: 331.06 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt2.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:10] Decoding of prompt2.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt3.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 1329
# Encoding Finished.
# Total bytes written: 1.06 MB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt3.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:34] Decoding of prompt3.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt4.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 220
# Encoding Finished.
# Total bytes written: 180.21 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt4.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:05] Decoding of prompt4.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt5.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 389
# Encoding Finished.
# Total bytes written: 318.02 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt5.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:10] Decoding of prompt5.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt6.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 552
# Encoding Finished.
# Total bytes written: 450.93 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt6.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:14] Decoding of prompt6.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt7.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 179
# Encoding Finished.
# Total bytes written: 146.78 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt7.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:04] Decoding of prompt7.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt8.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 312
# Encoding Finished.
# Total bytes written: 255.23 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt8.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:08] Decoding of prompt8.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt9.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 330
# Encoding Finished.
# Total bytes written: 269.91 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt9.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:08] Decoding of prompt9.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt10.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 234
# Encoding Finished.
# Total bytes written: 191.63 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt10.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:06] Decoding of prompt10.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt11.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 209
# Encoding Finished.
# Total bytes written: 171.24 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt11.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:05] Decoding of prompt11.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt12.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 439
# Encoding Finished.
# Total bytes written: 358.79 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt12.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:11] Decoding of prompt12.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt13.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 183
# Encoding Finished.
# Total bytes written: 150.04 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt13.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:04] Decoding of prompt13.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt14.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 330
# Encoding Finished.
# Total bytes written: 269.91 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt14.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:08] Decoding of prompt14.mp3 finished.
# ---------------------------------------------------------
# Input Filename: STDIN
# Output Filename: data/output/notewise_generator_samples/prompt15.mp3
# Raw input format: 2 channels, 16-bit, 44100 Hz
# ---------------------------------------------------------
# LibTwoLame 0.3.13 (http://www.twolame.org)
# Input : 44100 Hz, 2 channels
# Output: 44100 Hz, Stereo
# 256 kbps CBR MPEG-1 Layer II psycho model=3
# [De-emph:Off     Copyright:No     Original:Yes]
# [Padding:Off     CRC:Off          Energy:Off  ]
# ---------------------------------------------------------
# fluidsynth: warning: Failed to pin the sample data to RAM; swapping is possible.
# Encoding frame: 317
# Encoding Finished.
# Total bytes written: 259.31 KB.
# High Performance MPEG 1.0/2.0/2.5 Audio Player for Layers 1, 2 and 3
# 	version 1.25.6; written and copyright by Michael Hipp and others
# 	free software (LGPL) without any warranty but with best wishes
#
# Directory: data/output/notewise_generator_samples/
#
# Terminal control enabled, press 'h' for listing of keys and functions.
#
# Playing MPEG stream 1 of 1: prompt15.mp3 ...
#
# MPEG 1.0 L II cbr256 44100 stereo
#
# [0:08] Decoding of prompt15.mp3 finished.

# %%
music_dir = u'./data/output/notewise_generator_samples'

# %%
playlist_html, playlist_css, playlist_js=make_playlist(music_dir)
display(HTML(playlist_html))
display(HTML(playlist_css))
display(HTML(playlist_js))
# Out:
# <audio id="audio" preload="auto" tabindex="0" controls="" type="audio/mpeg">
#                     <source type="audio/mp3" src="./data/output/notewise_generator_samples/0.wav">Sorry, your browser does not support HTML5 audio.
#                     </audio>
# <ol id="playlist">
# <li class="active"><a href="./data/output/notewise_generator_samples/0.wav">0.wav</a>
#                     </li>
# <li><a href="./data/output/notewise_generator_samples/1.wav">1.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/10.wav">10.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/11.wav">11.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/12.wav">12.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/13.wav">13.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/14.wav">14.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/15.wav">15.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/2.wav">2.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/3.wav">3.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/4.wav">4.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/5.wav">5.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/6.wav">6.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/7.wav">7.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/8.wav">8.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/9.wav">9.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt0.wav">prompt0.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt1.wav">prompt1.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt10.wav">prompt10.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt11.wav">prompt11.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt12.wav">prompt12.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt13.wav">prompt13.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt14.wav">prompt14.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt15.wav">prompt15.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt2.wav">prompt2.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt3.wav">prompt3.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt4.wav">prompt4.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt5.wav">prompt5.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt6.wav">prompt6.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt7.wav">prompt7.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt8.wav">prompt8.wav</a></li>
# <li><a href="./data/output/notewise_generator_samples/prompt9.wav">prompt9.wav</a></li>
# </ol>
#     <style>
#     #playlist .active a{color:#CC0000;text-decoration:none;}
#     #playlist li a:hover{text-decoration:none;}
#     </style>
#     <script>
#     var audio;
#     var playlist;
#     var tracks;
#     var current;
#
#     init();
#     function init(){
#         current = 0;
#         audio = $('audio');
#         playlist = $('#playlist');
#         tracks = playlist.find('li a');
#         len = tracks.length - 1;
#         audio[0].volume = .90;
#         playlist.find('a').click(function(e){
#             e.preventDefault();
#             link = $(this);
#             current = link.parent().index();
#                     run(link, audio[0]);
#         });
#         audio[0].addEventListener('ended',function(e){
#             current++;
#             if(current == len){
#                 current = 0;
#                 link = playlist.find('a')[0];
#             }else{
#                 link = playlist.find('a')[current];
#             }
#             run($(link),audio[0]);
#         });
#     }
#     function run(link, player){
#             player.src = link.attr('href');
#             par = link.parent();
#             par.addClass('active').siblings().removeClass('active');
#             audio[0].load();
#             audio[0].play();
#     }
#     </script>
